# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 96.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.1 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="O4zTKpEylOWwoZVUKjaO")
project = rf.workspace("rachnera").project("parking-lot-j4ojc-bzfj1")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to parking-lot-1 in yolov8:: 100%|██████████| 4682/4682 [00:00<00:00, 5388.85it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8s.pt")

# %%
model.train(data="/content/parking-lot-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.val(data="/content/parking-lot-1/data.yaml", split="test")
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1218.0±607.9 MB/s, size: 52.8 KB)
# val: Scanning /content/parking-lot-1/test/labels... 86 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 86/86 1.4Kit/s 0.1s
# val: New cache created: /content/parking-lot-1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.4s
#                    all         86       4804      0.995      0.979      0.988      0.866
#                    car         79       2368      0.996      0.973      0.982      0.846
#                   free         86       2436      0.994      0.985      0.993      0.886
# Speed: 4.1ms preprocess, 14.6ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to /content/runs/detect/train3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# ...

# %%
results = model.predict(
    source="/content/carPark.mp4",
    conf=0.5,
    save=True,
    show=False,
    project="runs/detect",
    name="parking_test"
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/679) /content/carPark.mp4: 448x640 51 cars, 10 frees, 45.7ms
# video 1/1 (frame 2/679) /content/carPark.mp4: 448x640 52 cars, 10 frees, 13.7ms
# video 1/1 (frame 3/679) /content/carPark.mp4: 448x640 52 cars, 10 frees, 17.4ms
# video 1/1 (frame 4/679) /content/carPark.mp4: 448x640 52 cars, 10 frees, 13.9ms
# video 1/1 (frame 5/679) /content/carPark.mp4: 448x640 51 cars, 10 frees, 12.8ms
# ...

# %%
model.save("yolo8s_parklot.pt")
